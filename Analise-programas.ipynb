# %% [markdown]
# # Avaliando o enfrentamento político à crise climática nas eleições municipais do Brasil em 2024

# %% [markdown]
# Instalação das dependências:

# %%
# !pip install -r requirements.txt

# %% [markdown]
# O código abaixo gera os arquivos:
# - `analise-llm.log` com a resposta do modelo para cada página de cada plano de governo; e
# - `resultados.json` com a informação de quais páginas continham referências a propostas de prevenção de desastres climáticos em cada documento.
#
# **Importante:** a execução pode ser bastante demorada de acordo com a configuração da máquina que executa o LLM.

# %%
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate
from ollama import ResponseError
import pymupdf
import os
import json
from tqdm.notebook import tqdm
import logging

h = logging.FileHandler(filename='analise-llm.log')
h.setLevel(logging.INFO)
logger = logging.getLogger(__name__)
logger.addHandler(h)
logger.setLevel(logging.INFO)

logger.info('Iniciando execução.')

model = OllamaLLM(model="llama3.1:70b")

resultados = {}

top_dir = './pdfs'

prompt_template = """O texto a seguir, delimitado por triplos parênteses, foi extraído do plano de governo de um candidato a prefeito.
O texto contém alguma referência a uma proposta de plano de prevenção ou mitigação de riscos relacionados a eventos climáticos extremos (e.g.: inundações, deslizamentos, secas)?
Caso o texto não mencione o assunto, responda apenas NÃO
Caso o texto aborde o assunto, responda: SIM. trecho:<citação>
onde <citação> deve ser substituído por um trecho da frase que referencia o assunto.
Ignore eventuais erros na formatação do texto e responda apenas como pedido.
(((
    {texto}
)))
"""

prompt = ChatPromptTemplate.from_template(prompt_template)

chain = prompt | model

lista_cidades = os.listdir(top_dir)
try:
    for cidade in lista_cidades:
        res_cidade = {}
        print(f"Avaliando cidade de {cidade}")
        for pdf in os.listdir(os.path.join(top_dir, cidade)):
            refs_clima = []
            print(f'Avaliando "{pdf}":')
            for page in tqdm(pymupdf.open(os.path.join(top_dir, cidade, pdf))):
                text = page.get_text()
                retries = 0
                while True:
                    try:
                        response = chain.invoke({'texto': text})
                        break
                    except ResponseError as e:
                        retries += 1
                        if retries > 2:
                            raise e
                logger.info(f"{cidade}/{pdf}/{page.number + 1}:{response}")
                if "SIM" in response:
                    refs_clima.append(page.number + 1)
            res_cidade[pdf] = refs_clima
        resultados[cidade] = res_cidade
finally:
    h.close()
    json.dump(resultados, fp=open("resultados.json", "w"), ensure_ascii=False)
    json.dumps(resultados, ensure_ascii=False)

# %% [markdown]
# ## Exploração dos resultados

# %%
# !pip install pandas matplotlib

# %%
import json
import pandas as pd

with open("out/resultados.json", 'r') as res_file:
    res_json = json.load(res_file)

readable_results = []
for cid, v in res_json.items():
    for doc, refs in v.items():
        readable_results.append({'município': cid, 'documento': doc, 'aborda_tema': bool(refs), 'páginas': refs})

resultados = pd.DataFrame(readable_results)

resultados

# %%
unica_mencao = [['município', 'candidata(o)', 'proposta validada', 'justificativa'],
                ['Caracaraí', 'Gildeone Roque', 'N', 'meios de financiamento de sistema de detecção de tempestades, sem especificar finalidade'],
                ['Rio de Janeiro', 'Eduardo Paes', 'S', 'houve atenção mas condensada em uma página'],
                ['Batayporã', 'Germino Roz', 'N', 'apenas drenagem do pavimento'],
                ['São Luiz Paraitinga', 'Flavio Bonafe', 'N', 'drenagem para evitar acúmulo de água'],
                ['Itati', 'Jussara Bobsin', 'S', 'houve atenção mas condensada em uma página'],
                ['São Paulo', 'Pablo Marçal', 'N', 'revitalização de parques, sem menção ao enfrentamento de desastres'],
                ['Três Forquilhas', 'Bruno', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
                ['Igarassu', 'Miguel Ricardo', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
                ['Igarassu', 'Professora Elcione', 'S', 'houve atenção mas condensada em uma página'],
                ['Barreiros', 'Claudio da Cooates', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
                ['Barreiros', 'Carlinhos da Pedreira', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
                ['Jurema', 'Branco de Geraldo', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
                ['Jurema', 'Léo Ramos', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
                ['Ribeirão das Neves', 'Vicente Mendonca', 'S', 'enfrentamento sem reconhecimento do papel da crise climática'],
               ]

unica_mencao = pd.DataFrame(unica_mencao[1:], columns=unica_mencao[0])

unica_mencao

# %%
import os

dados_tse = pd.read_csv(os.path.join('dados_manuais', 'prefeituras_clima_dados_tse.csv'), sep=';')
resultados2 = resultados.merge(dados_tse, how='left', on=['município', 'documento'])
resultados = resultados2.merge(unica_mencao, how='left', on=['município', 'candidata(o)'])

resultados.loc[resultados['proposta validada'] == 'N', 'aborda_tema'] = False

resultados.drop(['documento', 'justificativa', 'proposta validada', 'páginas'], axis=1, inplace=True)

resultados
# Out:
#                   município  aborda_tema           candidata(o)  \
# 0                 Caracaraí        False           Diego Farias
# 1                 Caracaraí        False           Diane Coelho
# 2                 Caracaraí        False           Antônio Reis
# 3                 Caracaraí        False         Gildeone Roque
# 4            Rio de Janeiro         True      Alexandre Ramagem
# 5            Rio de Janeiro         True           Eduardo Paes
# 6                 Batayporã        False            Germino Roz
# 7                 Batayporã        False      Edmilson Gaiseiro
# 8       São Luiz Paraitinga        False          Flavio Bonafe
# 9       São Luiz Paraitinga         True         Antonio Ozorio
# 10      São Luiz Paraitinga        False            Alex Torres
# 11                    Itati         True               Madalena
# 12                    Itati         True         Jussara Bobsin
# 13                São Paulo         True       Guilherme Boulos
# 14                São Paulo         True          Ricardo Nunes
# 15                São Paulo        False           Pablo Marçal
# 16  Jaboatão dos Guararapes         True            Elias Gomes
# 17  Jaboatão dos Guararapes        False           Daniel Alves
# 18  Jaboatão dos Guararapes         True          Mano Medeiros
# 19  Jaboatão dos Guararapes         True        Clarissa Tércio
# 20          Três Forquilhas         True                  Bruno
# 21          Três Forquilhas         True                   Lola
# 22          Três Forquilhas         True                 Jarbas
# 23                 Itaiçaba        False            Frank Gomes
# 24                 Itaiçaba        False               Genilson
# 25                 Itaiçaba        False       Antoniel Holanda
# 26                 Itaiçaba        False               Nilsinho
# 27           Belo Horizonte         True           Bruno Engler
# 28           Belo Horizonte         True             Fuad Noman
# 29           Belo Horizonte         True         Mauro Tramonte
# 30                 Salvador        False         Geraldo Júnior
# 31                 Salvador         True             Bruno Reis
# 32                 Igarassu         True         Miguel Ricardo
# 33                 Igarassu         True     Professora Elcione
# 34                Barreiros         True     Claudio da Cooates
# 35                Barreiros        False        Paula Verissimo
# 36                Barreiros         True                  Pedão
# 37                Barreiros         True           Eurico Cézar
# 38                Barreiros         True  Carlinhos da Pedreira
# 39                   Jurema         True      Branco de Geraldo
# 40                   Jurema         True              Léo Ramos
# 41                   Cortês        False         Professor Eron
# 42                   Cortês        False                Geninho
# 43                   Cortês         True           Fatima Borba
# 44          Vitória do Jari        False            Luiz Beirão
# 45          Vitória do Jari         True             Ary Duarte
# 46          Vitória do Jari        False             Paulo Lobo
# 47       Ribeirão das Neves        False                  Túlio
# 48       Ribeirão das Neves         True        Diogo Fernandes
# 49       Ribeirão das Neves         True       Vicente Mendonca
# 50                   Recife         True            João Campos
# 51                   Recife         True         Gilson Machado
#
#           partido                                          coligação  \
# 0            PSDB     PDT / Federação PSDB CIDADANIA(PSDB/CIDADANIA)
# 1              PP                           PP / REPUBLICANOS / PODE
# 2             MDB                                           MDB / PL
# 3            NOVO                                               NOVO
# 4              PL                            PL / MDB / REPUBLICANOS
# 5             PSD  PODE / PRD / DC / AGIR / SOLIDARIEDADE / AVANT...
# 6            PSDB  PP / UNIÃO / PODE / Federação BRASIL DA ESPERA...
# 7             MDB           PDT / REPUBLICANOS / SOLIDARIEDADE / MDB
# 8             MDB  MDB / PSB / SOLIDARIEDADE / Federação BRASIL D...
# 9             PSD  PSD / UNIÃO / PRD / PODE / Federação PSDB CIDA...
# 10             PL         REPUBLICANOS / PP / MOBILIZA / AVANTE / PL
# 11             PP                                            PP / PL
# 12            PDT                                          PDT / MDB
# 13           PSOL  Federação PSOL REDE(PSOL/REDE) / Federação BRA...
# 14            MDB  PP / MDB / PL / PSD / REPUBLICANOS / SOLIDARIE...
# 15           PRTB                                               PRTB
# 16             PT  Federação BRASIL DA ESPERANÇA - FE BRASIL(PT/P...
# 17         AVANTE                                             AVANTE
# 18             PL  PL / UNIÃO / DC / NOVO / MOBILIZA / PRD / PSD ...
# 19             PP                                   PP / PODE / AGIR
# 20             PT  Federação BRASIL DA ESPERANÇA - FE BRASIL(PT/P...
# 21             PP                                                 PP
# 22            MDB                                                MDB
# 23            PSB                                   PSB / PDT / PODE
# 24             PL                                                 PL
# 25             PT  PSD / Federação BRASIL DA ESPERANÇA - FE BRASI...
# 26             PP                                         PP / UNIÃO
# 27             PL                                            PP / PL
# 28            PSD  SOLIDARIEDADE / UNIÃO / PRD / PSD / AGIR / AVA...
# 29   REPUBLICANOS                                REPUBLICANOS / NOVO
# 30            MDB  MDB / Federação BRASIL DA ESPERANÇA - FE BRASI...
# 31          UNIÃO  UNIÃO / REPUBLICANOS / PP / PDT / PL / PRD / D...
# 32   REPUBLICANOS  REPUBLICANOS / MDB / PODE / PSB / AGIR / Feder...
# 33           PSDB  PP / PDT / PL / UNIÃO / PSD / SOLIDARIEDADE / ...
# 34            PDT                                        PDT / UNIÃO
# 35           PODE  PRD / Federação BRASIL DA ESPERANÇA - FE BRASI...
# 36  SOLIDARIEDADE                 SOLIDARIEDADE / MDB / AVANTE / PSB
# 37           PSOL                     Federação PSOL REDE(PSOL/REDE)
# 38             PP                                      PP / PL / PSD
# 39             PT  REPUBLICANOS / Federação BRASIL DA ESPERANÇA -...
# 40            PSB                                        PSB / UNIÃO
# 41  SOLIDARIEDADE  SOLIDARIEDADE / Federação BRASIL DA ESPERANÇA ...
# 42            PSB                                          PSB / MDB
# 43           PSDB  REPUBLICANOS / PSD / Federação PSDB CIDADANIA(...
# 44             PP                                     PP / PRD / MDB
# 45          UNIÃO             SOLIDARIEDADE / PDT / UNIÃO / PSD / PL
# 46           AGIR                                               AGIR
# 47             PP  PP / REPUBLICANOS / PDT / MDB / PRD / MOBILIZA...
# 48           NOVO                                               NOVO
# 49             PT  Federação BRASIL DA ESPERANÇA - FE BRASIL(PT/P...
# 50            PSB  PSB / Federação BRASIL DA ESPERANÇA - FE BRASI...
# 51             PL                                                 PL
#
#      resultado
# 0   não eleita
# 1       eleita
# 2   não eleita
# 3   não eleita
# 4   não eleita
# 5       eleita
# 6       eleita
# 7   não eleita
# 8   não eleita
# 9   não eleita
# 10      eleita
# 11      eleita
# 12  não eleita
# 13    2o turno
# 14    2o turno
# 15  não eleita
# 16  não eleita
# 17  não eleita
# 18      eleita
# 19  não eleita
# 20  não eleita
# 21      eleita
# 22  não eleita
# 23  não eleita
# 24  não eleita
# 25      eleita
# 26  não eleita
# 27    2o turno
# 28    2o turno
# 29  não eleita
# 30  não eleita
# 31      eleita
# 32  não eleita
# 33      eleita
# 34  não eleita
# 35  não eleita
# 36  não eleita
# 37  não eleita
# 38      eleita
# 39      eleita
# 40  não eleita
# 41  não eleita
# 42  não eleita
# 43      eleita
# 44  não eleita
# 45      eleita
# 46  não eleita
# 47      eleita
# 48  não eleita
# 49  não eleita
# 50      eleita
# 51  não eleita

# %% [markdown]
# ### Exportando para Excel

# %%
# !pip install xlsxwriter

# %%
resultados.to_excel('prefeituras_clima_resumo_v2.xlsx', index=False)
